# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 610

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="


# Set up lists to hold response info
name_info = []
cloud_info = []
country_info = []
date_info = []
humidity_info = []
lat_info = []
lon_info = []   
temp_max = []
wind_speed = []

# Start the counters
count = 1 # counter to count the number of calls to API
err = 0 # error count to record how many cities the API responds back with no data.
sets = 1 # counter to count the number of call sets

#Get current time
t0 = time.time()

#Log file print statement
print(f"Beginning Data Retrieval \n------------------------------------")

# Loop through the list of cities and perform a request for data on each
for city in cities:
    try: 
        weather_response = requests.get(query_url + city)
        name_info.append(weather_response.json()['name'])
        cloud_info.append(weather_response.json()['clouds']['all'])
        country_info.append(weather_response.json()['sys']['country'])
        date_info.append(weather_response.json()['dt'])
        humidity_info.append(weather_response.json()['main']['humidity'])
        lat_info.append(weather_response.json()['coord']['lat'])
        lon_info.append(weather_response.json()['coord']['lon'])
        temp_max.append(weather_response.json()['main']['temp_max'])
        wind_speed.append(weather_response.json()['wind']['speed'])
        city_record = weather_response.json()['name']
    
        # Print call log counter
        print(f"Processing Record {count} of Set {sets} | {city_record}")
    
    # If no record found, skip to the next API call      
    except KeyError:
        print("City not found. Skipping...")
        err= err+1
    # Increase counter by one
    count = count + 1  
    if count == 51: # loop to limit 50 API calls per minute. The API is capped at 60 per min.
        print("Resting...")
        t1=time.time()
        count = 1 
        sets = sets+1
        time.sleep(60-(t1-t0))
        t0 = time.time()
        
print("Last Call")
print(f'{err} cities returned KeyErrors and were skipped')
# Out:
# Beginning Data Retrieval
# ------------------------------------
# Processing Record 1 of Set 1 | Souillac
# Processing Record 2 of Set 1 | Aksarka
# Processing Record 3 of Set 1 | Hermanus
# Processing Record 4 of Set 1 | Kununurra
# Processing Record 5 of Set 1 | Ushuaia
# Processing Record 6 of Set 1 | Punta Arenas
# Processing Record 7 of Set 1 | Taga
# Processing Record 8 of Set 1 | Avarua
# Processing Record 9 of Set 1 | Qaanaaq
# Processing Record 10 of Set 1 | Mataura
# Processing Record 11 of Set 1 | Geraldton
# Processing Record 12 of Set 1 | Tuktoyaktuk
# Processing Record 13 of Set 1 | Kodinsk
# Processing Record 14 of Set 1 | Tilichiki
# Processing Record 15 of Set 1 | Cidreira
# City not found. Skipping...
# Processing Record 17 of Set 1 | Angoche
# Processing Record 18 of Set 1 | Clyde River
# City not found. Skipping...
# Processing Record 20 of Set 1 | Kruisfontein
# City not found. Skipping...
# Processing Record 22 of Set 1 | Lata
# Processing Record 23 of Set 1 | Chapais
# Processing Record 24 of Set 1 | Kampot
# Processing Record 25 of Set 1 | Katsuura
# Processing Record 26 of Set 1 | Portales
# Processing Record 27 of Set 1 | Natal
# Processing Record 28 of Set 1 | Bubaque
# Processing Record 29 of Set 1 | Bambous Virieux
# Processing Record 30 of Set 1 | Ostrovnoy
# City not found. Skipping...
# Processing Record 32 of Set 1 | Rikitea
# Processing Record 33 of Set 1 | Barrow
# City not found. Skipping...
# Processing Record 35 of Set 1 | Hithadhoo
# Processing Record 36 of Set 1 | Iqaluit
# City not found. Skipping...
# Processing Record 38 of Set 1 | Vaini
# City not found. Skipping...
# Processing Record 40 of Set 1 | Bull Savanna
# Processing Record 41 of Set 1 | Port Alfred
# Processing Record 42 of Set 1 | Upernavik
# Processing Record 43 of Set 1 | Mineiros
# Processing Record 44 of Set 1 | Ilulissat
# Processing Record 45 of Set 1 | Hilo
# City not found. Skipping...
# Processing Record 47 of Set 1 | Esperance
# Processing Record 48 of Set 1 | Shimoda
# Processing Record 49 of Set 1 | Leningradskiy
# Processing Record 50 of Set 1 | Saint-Philippe
# Resting...
# Processing Record 1 of Set 2 | Ojinaga
# Processing Record 2 of Set 2 | El Fuerte
# Processing Record 3 of Set 2 | Petropavl
# Processing Record 4 of Set 2 | Havoysund
# Processing Record 5 of Set 2 | Yellowknife
# Processing Record 6 of Set 2 | Carnarvon
# Processing Record 7 of Set 2 | Mar del Plata
# Processing Record 8 of Set 2 | Bredasdorp
# Processing Record 9 of Set 2 | Padang
# Processing Record 10 of Set 2 | Ion Roata
# Processing Record 11 of Set 2 | Palmas
# Processing Record 12 of Set 2 | Atuona
# Processing Record 13 of Set 2 | New Norfolk
# Processing Record 14 of Set 2 | Oyem
# Processing Record 15 of Set 2 | Puerto Ayora
# Processing Record 16 of Set 2 | Pimentel
# Processing Record 17 of Set 2 | Bali
# Processing Record 18 of Set 2 | Marietta
# Processing Record 19 of Set 2 | Provideniya
# Processing Record 20 of Set 2 | Okhotsk
# Processing Record 21 of Set 2 | Holt
# Processing Record 22 of Set 2 | Kapaa
# Processing Record 23 of Set 2 | Hami
# Processing Record 24 of Set 2 | Chuy
# Processing Record 25 of Set 2 | Georgetown
# Processing Record 26 of Set 2 | Albany
# Processing Record 27 of Set 2 | Lavrentiya
# Processing Record 28 of Set 2 | Naze
# Processing Record 29 of Set 2 | Itarema
# Processing Record 30 of Set 2 | Ambon
# Processing Record 31 of Set 2 | Tuatapere
# Processing Record 32 of Set 2 | Busselton
# Processing Record 33 of Set 2 | Trindade
# Processing Record 34 of Set 2 | Kandi
# Processing Record 35 of Set 2 | Mortka
# Processing Record 36 of Set 2 | Pochutla
# City not found. Skipping...
# Processing Record 38 of Set 2 | Whitehorse
# Processing Record 39 of Set 2 | Nikolskoye
# Processing Record 40 of Set 2 | Norman Wells
# Processing Record 41 of Set 2 | Cockburn Town
# City not found. Skipping...
# Processing Record 43 of Set 2 | Nizhniy Baskunchak
# Processing Record 44 of Set 2 | Matara
# Processing Record 45 of Set 2 | Harper
# Processing Record 46 of Set 2 | Bluff
# Processing Record 47 of Set 2 | Kaitangata
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 of Set 2 | Jamestown
# Resting...
# Processing Record 1 of Set 3 | Tripoli
# Processing Record 2 of Set 3 | Arraial do Cabo
# Processing Record 3 of Set 3 | Ketchikan
# Processing Record 4 of Set 3 | Luderitz
# Processing Record 5 of Set 3 | Isangel
# Processing Record 6 of Set 3 | Bryan
# Processing Record 7 of Set 3 | Hobart
# Processing Record 8 of Set 3 | Tual
# Processing Record 9 of Set 3 | Lomovka
# Processing Record 10 of Set 3 | Saskylakh
# Processing Record 11 of Set 3 | Tamsweg
# Processing Record 12 of Set 3 | Riyadh
# City not found. Skipping...
# Processing Record 14 of Set 3 | Sao Paulo de Olivenca
# Processing Record 15 of Set 3 | Jalu
# Processing Record 16 of Set 3 | Cabo San Lucas
# Processing Record 17 of Set 3 | San Carlos de Bariloche
# Processing Record 18 of Set 3 | Half Moon Bay
# City not found. Skipping...
# Processing Record 20 of Set 3 | Richards Bay
# Processing Record 21 of Set 3 | Santa Ana
# Processing Record 22 of Set 3 | Thompson
# Processing Record 23 of Set 3 | Tromso
# Processing Record 24 of Set 3 | Puri
# Processing Record 25 of Set 3 | Port Elizabeth
# Processing Record 26 of Set 3 | Atasu
# City not found. Skipping...
# Processing Record 28 of Set 3 | Pevek
# Processing Record 29 of Set 3 | Kuching
# Processing Record 30 of Set 3 | Nouakchott
# Processing Record 31 of Set 3 | Nara
# Processing Record 32 of Set 3 | Manyana
# Processing Record 33 of Set 3 | Spearfish
# Processing Record 34 of Set 3 | Susanville
# City not found. Skipping...
# Processing Record 36 of Set 3 | Alta Floresta
# Processing Record 37 of Set 3 | Torbay
# Processing Record 38 of Set 3 | Cape Town
# Processing Record 39 of Set 3 | Alice Springs
# Processing Record 40 of Set 3 | Victoria
# Processing Record 41 of Set 3 | Busayra
# Processing Record 42 of Set 3 | Havre-Saint-Pierre
# City not found. Skipping...
# Processing Record 44 of Set 3 | Snasa
# Processing Record 45 of Set 3 | Chokurdakh
# Processing Record 46 of Set 3 | Namatanai
# City not found. Skipping...
# Processing Record 48 of Set 3 | Yangjiang
# Processing Record 49 of Set 3 | Bethel
# Processing Record 50 of Set 3 | Butaritari
# Resting...
# Processing Record 1 of Set 4 | Salalah
# City not found. Skipping...
# Processing Record 3 of Set 4 | Rolla
# Processing Record 4 of Set 4 | Phanat Nikhom
# Processing Record 5 of Set 4 | Kodiak
# Processing Record 6 of Set 4 | Guerrero Negro
# Processing Record 7 of Set 4 | Silver City
# Processing Record 8 of Set 4 | Muros
# Processing Record 9 of Set 4 | Benghazi
# Processing Record 10 of Set 4 | Saint Anthony
# Processing Record 11 of Set 4 | San Patricio
# Processing Record 12 of Set 4 | Wageningen
# Processing Record 13 of Set 4 | Khatanga
# Processing Record 14 of Set 4 | Nong Chik
# Processing Record 15 of Set 4 | Sumoto
# Processing Record 16 of Set 4 | Abu Samrah
# Processing Record 17 of Set 4 | Beringovskiy
# Processing Record 18 of Set 4 | Tiznit
# Processing Record 19 of Set 4 | Constitucion
# Processing Record 20 of Set 4 | Lucapa
# Processing Record 21 of Set 4 | Sioux Lookout
# Processing Record 22 of Set 4 | Portobelo
# Processing Record 23 of Set 4 | Ponta do Sol
# Processing Record 24 of Set 4 | Longyearbyen
# Processing Record 25 of Set 4 | Monte Santo
# City not found. Skipping...
# Processing Record 27 of Set 4 | Lebu
# Processing Record 28 of Set 4 | Allen
# Processing Record 29 of Set 4 | Qasigiannguit
# Processing Record 30 of Set 4 | Libertador General San Martin
# Processing Record 31 of Set 4 | Cachoeira do Sul
# Processing Record 32 of Set 4 | Redwater
# Processing Record 33 of Set 4 | Ghanzi
# Processing Record 34 of Set 4 | Santiago
# Processing Record 35 of Set 4 | East London
# Processing Record 36 of Set 4 | Joensuu
# City not found. Skipping...
# Processing Record 38 of Set 4 | Poughkeepsie
# City not found. Skipping...
# Processing Record 40 of Set 4 | Mahebourg
# City not found. Skipping...
# Processing Record 42 of Set 4 | Meulaboh
# Processing Record 43 of Set 4 | Togur
# Processing Record 44 of Set 4 | Pisco
# Processing Record 45 of Set 4 | Amurzet
# Processing Record 46 of Set 4 | Davila
# Processing Record 47 of Set 4 | Mbini
# Processing Record 48 of Set 4 | Paamiut
# Processing Record 49 of Set 4 | Claresholm
# Processing Record 50 of Set 4 | Medveditskiy
# Resting...
# City not found. Skipping...
# Processing Record 2 of Set 5 | Balotra
# Processing Record 3 of Set 5 | Berdigestyakh
# City not found. Skipping...
# Processing Record 5 of Set 5 | Kasane
# City not found. Skipping...
# Processing Record 7 of Set 5 | Lasa
# Processing Record 8 of Set 5 | Turbat
# Processing Record 9 of Set 5 | Durusu
# Processing Record 10 of Set 5 | Albion
# City not found. Skipping...
# Processing Record 12 of Set 5 | Bathsheba
# Processing Record 13 of Set 5 | Quelimane
# Processing Record 14 of Set 5 | Avera
# Processing Record 15 of Set 5 | Puerto Escondido
# Processing Record 16 of Set 5 | Lagoa
# Processing Record 17 of Set 5 | Antropovo
# Processing Record 18 of Set 5 | Majene
# Processing Record 19 of Set 5 | Ambanja
# Processing Record 20 of Set 5 | Aklavik
# Processing Record 21 of Set 5 | Sinnamary
# Processing Record 22 of Set 5 | Brownsville
# Processing Record 23 of Set 5 | Huai Yot
# Processing Record 24 of Set 5 | Maun
# Processing Record 25 of Set 5 | Ribeira Grande
# City not found. Skipping...
# Processing Record 27 of Set 5 | Kuusamo
# Processing Record 28 of Set 5 | Saint-Louis
# City not found. Skipping...
# Processing Record 30 of Set 5 | Talitsy
# Processing Record 31 of Set 5 | Sarh
# Processing Record 32 of Set 5 | Tala
# Processing Record 33 of Set 5 | Kavaratti
# Processing Record 34 of Set 5 | Pacific Grove
# Processing Record 35 of Set 5 | Peniche
# Processing Record 36 of Set 5 | Husavik
# Processing Record 37 of Set 5 | Seoul
# Processing Record 38 of Set 5 | Carlos Antonio Lopez
# Processing Record 39 of Set 5 | Castro
# Processing Record 40 of Set 5 | Surgut
# Processing Record 41 of Set 5 | Ayan
# Processing Record 42 of Set 5 | Bereda
# Processing Record 43 of Set 5 | Talcahuano
# Processing Record 44 of Set 5 | Usinsk
# Processing Record 45 of Set 5 | College
# Processing Record 46 of Set 5 | Ondjiva
# Processing Record 47 of Set 5 | Gold Coast
# City not found. Skipping...
# Processing Record 49 of Set 5 | Flinders
# Processing Record 50 of Set 5 | Keti Bandar
# Resting...
# Processing Record 1 of Set 6 | Biak
# Processing Record 2 of Set 6 | Masuda
# Processing Record 3 of Set 6 | Katherine
# Processing Record 4 of Set 6 | Brewster
# City not found. Skipping...
# Processing Record 6 of Set 6 | Dekar
# Processing Record 7 of Set 6 | Dourbali
# Processing Record 8 of Set 6 | Kirakira
# City not found. Skipping...
# Processing Record 10 of Set 6 | Laje
# Processing Record 11 of Set 6 | Mayo
# Processing Record 12 of Set 6 | Kaduna
# City not found. Skipping...
# Processing Record 14 of Set 6 | Petropavlovsk-Kamchatskiy
# Processing Record 15 of Set 6 | Chumikan
# City not found. Skipping...
# Processing Record 17 of Set 6 | Kot Samaba
# Processing Record 18 of Set 6 | Marzuq
# Processing Record 19 of Set 6 | Sandakan
# Processing Record 20 of Set 6 | Savinka
# Processing Record 21 of Set 6 | Raglan
# Processing Record 22 of Set 6 | Port Macquarie
# Processing Record 23 of Set 6 | Falam
# Processing Record 24 of Set 6 | Sirjan
# Processing Record 25 of Set 6 | Palembang
# Processing Record 26 of Set 6 | Balakhninskiy
# City not found. Skipping...
# Processing Record 28 of Set 6 | Hualmay
# Processing Record 29 of Set 6 | Santa Rosa
# Processing Record 30 of Set 6 | Gladstone
# Processing Record 31 of Set 6 | Shitanjing
# Processing Record 32 of Set 6 | Ahuimanu
# Processing Record 33 of Set 6 | Muhammadabad
# Processing Record 34 of Set 6 | Kuala Lipis
# City not found. Skipping...
# Processing Record 36 of Set 6 | Rundu
# Processing Record 37 of Set 6 | Fairbanks
# Processing Record 38 of Set 6 | Dhidhdhoo
# Processing Record 39 of Set 6 | Sao Filipe
# Processing Record 40 of Set 6 | Sibolga
# Processing Record 41 of Set 6 | Timmins
# City not found. Skipping...
# Processing Record 43 of Set 6 | Airai
# Processing Record 44 of Set 6 | Gat
# Processing Record 45 of Set 6 | Naryan-Mar
# Processing Record 46 of Set 6 | Saldanha
# Processing Record 47 of Set 6 | Carutapera
# City not found. Skipping...
# Processing Record 49 of Set 6 | San Andres
# Processing Record 50 of Set 6 | Nanortalik
# Resting...
# Processing Record 1 of Set 7 | Ulaanbaatar
# Processing Record 2 of Set 7 | Talnakh
# Processing Record 3 of Set 7 | Teguise
# Processing Record 4 of Set 7 | Tiksi
# Processing Record 5 of Set 7 | Fort Nelson
# Processing Record 6 of Set 7 | Nouadhibou
# Processing Record 7 of Set 7 | Rawson
# Processing Record 8 of Set 7 | Lodja
# Processing Record 9 of Set 7 | Ixtapa
# City not found. Skipping...
# Processing Record 11 of Set 7 | Belaya Gora
# Processing Record 12 of Set 7 | Shache
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 15 of Set 7 | Tessalit
# Processing Record 16 of Set 7 | Faanui
# Processing Record 17 of Set 7 | Eureka
# Processing Record 18 of Set 7 | Shirokiy
# Processing Record 19 of Set 7 | Ibb
# Processing Record 20 of Set 7 | Narasannapeta
# Processing Record 21 of Set 7 | Touros
# Processing Record 22 of Set 7 | Tasiilaq
# Processing Record 23 of Set 7 | Otane
# Processing Record 24 of Set 7 | Bo Phloi
# Processing Record 25 of Set 7 | Puerto del Rosario
# Processing Record 26 of Set 7 | Yaan
# Processing Record 27 of Set 7 | Ancud
# Processing Record 28 of Set 7 | Sindor
# Processing Record 29 of Set 7 | Sehore
# Processing Record 30 of Set 7 | Nagorsk
# Processing Record 31 of Set 7 | Port Hardy
# Processing Record 32 of Set 7 | San Ramon
# City not found. Skipping...
# Processing Record 34 of Set 7 | Loudi
# Processing Record 35 of Set 7 | Saurimo
# Processing Record 36 of Set 7 | Sambava
# Processing Record 37 of Set 7 | Perth
# Processing Record 38 of Set 7 | Waipawa
# Processing Record 39 of Set 7 | Sabang
# Processing Record 40 of Set 7 | Yantal
# Processing Record 41 of Set 7 | Hervey Bay
# Processing Record 42 of Set 7 | Dubbo
# City not found. Skipping...
# Processing Record 44 of Set 7 | Batemans Bay
# Processing Record 45 of Set 7 | Komsomolskiy
# Processing Record 46 of Set 7 | Bilma
# Processing Record 47 of Set 7 | Yar-Sale
# Processing Record 48 of Set 7 | Alofi
# Processing Record 49 of Set 7 | Hambantota
# Processing Record 50 of Set 7 | Kumo
# Resting...
# Processing Record 1 of Set 8 | Distraccion
# Processing Record 2 of Set 8 | Sisimiut
# Processing Record 3 of Set 8 | Gberia Fotombu
# Processing Record 4 of Set 8 | Ponta Delgada
# Processing Record 5 of Set 8 | Lorengau
# Processing Record 6 of Set 8 | Panikian
# Processing Record 7 of Set 8 | Payo
# Processing Record 8 of Set 8 | Itoman
# Processing Record 9 of Set 8 | Durban
# Processing Record 10 of Set 8 | Salinopolis
# Processing Record 11 of Set 8 | Pellerd
# Processing Record 12 of Set 8 | Kavieng
# Processing Record 13 of Set 8 | Sechura
# Processing Record 14 of Set 8 | Tezu
# Processing Record 15 of Set 8 | Camacha
# Processing Record 16 of Set 8 | Mehamn
# Processing Record 17 of Set 8 | Potam
# Processing Record 18 of Set 8 | Teknaf
# Processing Record 19 of Set 8 | Cherskiy
# Processing Record 20 of Set 8 | Goundam
# City not found. Skipping...
# Processing Record 22 of Set 8 | Grindavik
# Processing Record 23 of Set 8 | Caconda
# Processing Record 24 of Set 8 | Russell
# Processing Record 25 of Set 8 | Homer
# City not found. Skipping...
# Processing Record 27 of Set 8 | Buala
# City not found. Skipping...
# Processing Record 29 of Set 8 | Ilhabela
# Processing Record 30 of Set 8 | Paita
# City not found. Skipping...
# Processing Record 32 of Set 8 | Ahvaz
# Processing Record 33 of Set 8 | Porto Novo
# Processing Record 34 of Set 8 | Vila Velha
# Processing Record 35 of Set 8 | North Bend
# Processing Record 36 of Set 8 | Murgab
# Processing Record 37 of Set 8 | Grand Gaube
# Processing Record 38 of Set 8 | Rabo de Peixe
# Processing Record 39 of Set 8 | Flin Flon
# Processing Record 40 of Set 8 | San Quintin
# Processing Record 41 of Set 8 | Deputatskiy
# Processing Record 42 of Set 8 | Tura
# Processing Record 43 of Set 8 | Saint George
# Processing Record 44 of Set 8 | Puerto Carreno
# City not found. Skipping...
# Processing Record 46 of Set 8 | Leshukonskoye
# Processing Record 47 of Set 8 | Ahipara
# Processing Record 48 of Set 8 | Sanski Most
# Processing Record 49 of Set 8 | Nemuro
# Processing Record 50 of Set 8 | Margate
# Resting...
# Processing Record 1 of Set 9 | Coari
# Processing Record 2 of Set 9 | Kayerkan
# Processing Record 3 of Set 9 | Alto Araguaia
# Processing Record 4 of Set 9 | Svobodnyy
# Processing Record 5 of Set 9 | Mount Gambier
# Processing Record 6 of Set 9 | Hay River
# Processing Record 7 of Set 9 | Ekhabi
# Processing Record 8 of Set 9 | Umbertide
# Processing Record 9 of Set 9 | Zory
# Processing Record 10 of Set 9 | Namibe
# Processing Record 11 of Set 9 | Sitka
# Processing Record 12 of Set 9 | Dingle
# Processing Record 13 of Set 9 | Yulara
# Processing Record 14 of Set 9 | Evensk
# Processing Record 15 of Set 9 | High Level
# Processing Record 16 of Set 9 | Vila Franca do Campo
# Processing Record 17 of Set 9 | Grenville
# Processing Record 18 of Set 9 | Palmerston
# Processing Record 19 of Set 9 | Mount Isa
# Processing Record 20 of Set 9 | Zabol
# Processing Record 21 of Set 9 | Westport
# Processing Record 22 of Set 9 | Xiaoweizhai
# Processing Record 23 of Set 9 | Dongsheng
# Processing Record 24 of Set 9 | Lichtenburg
# Processing Record 25 of Set 9 | Kahului
# Processing Record 26 of Set 9 | Dikson
# Processing Record 27 of Set 9 | Las Vegas
# Processing Record 28 of Set 9 | Maryborough
# Processing Record 29 of Set 9 | Pangody
# Processing Record 30 of Set 9 | Kalamare
# Processing Record 31 of Set 9 | Sabha
# Processing Record 32 of Set 9 | Andreapol
# Processing Record 33 of Set 9 | Tautira
# Processing Record 34 of Set 9 | Acapulco
# Processing Record 35 of Set 9 | Mpulungu
# Processing Record 36 of Set 9 | Gamba
# Processing Record 37 of Set 9 | Lompoc
# Processing Record 38 of Set 9 | Boa Vista
# Processing Record 39 of Set 9 | Bandarbeyla
# Processing Record 40 of Set 9 | Vilhena
# Processing Record 41 of Set 9 | Saint-Augustin
# City not found. Skipping...
# Processing Record 43 of Set 9 | Waingapu
# Processing Record 44 of Set 9 | Pedernales
# Processing Record 45 of Set 9 | Ternate
# Processing Record 46 of Set 9 | Cedar City
# Processing Record 47 of Set 9 | Alexandria
# Processing Record 48 of Set 9 | Vandra
# Processing Record 49 of Set 9 | Namwala
# Processing Record 50 of Set 9 | Samarai
# Resting...
# Processing Record 1 of Set 10 | Pareora
# Processing Record 2 of Set 10 | Venado Tuerto
# City not found. Skipping...
# Processing Record 4 of Set 10 | Poyarkovo
# Processing Record 5 of Set 10 | Severo-Kurilsk
# Processing Record 6 of Set 10 | Brae
# Processing Record 7 of Set 10 | Macduff
# Processing Record 8 of Set 10 | Iskateley
# Processing Record 9 of Set 10 | Jinan
# Processing Record 10 of Set 10 | Grootfontein
# Processing Record 11 of Set 10 | Vangaindrano
# Processing Record 12 of Set 10 | Garissa
# Processing Record 13 of Set 10 | Wahiawa
# Processing Record 14 of Set 10 | Sorland
# Processing Record 15 of Set 10 | Stolac
# Processing Record 16 of Set 10 | San Miguel
# Processing Record 17 of Set 10 | Hamilton
# Processing Record 18 of Set 10 | Moron
# Processing Record 19 of Set 10 | Fare
# Processing Record 20 of Set 10 | Sandy Bay
# Processing Record 21 of Set 10 | Portland
# Processing Record 22 of Set 10 | Channel-Port aux Basques
# Processing Record 23 of Set 10 | Lahij
# Processing Record 24 of Set 10 | Takoradi
# Processing Record 25 of Set 10 | West Bay
# Processing Record 26 of Set 10 | Zhezkazgan
# Processing Record 27 of Set 10 | Nykoping
# Processing Record 28 of Set 10 | Nalut
# City not found. Skipping...
# Processing Record 30 of Set 10 | Maragogi
# Processing Record 31 of Set 10 | Tarata
# Processing Record 32 of Set 10 | Fernie
# Processing Record 33 of Set 10 | San Matias
# Processing Record 34 of Set 10 | Mega
# Processing Record 35 of Set 10 | Sivaki
# Processing Record 36 of Set 10 | San Angelo
# Processing Record 37 of Set 10 | Praia
# Processing Record 38 of Set 10 | Hasaki
# Processing Record 39 of Set 10 | Bucerias
# Processing Record 40 of Set 10 | Belawan
# City not found. Skipping...
# Processing Record 42 of Set 10 | Nefteyugansk
# Processing Record 43 of Set 10 | Haines Junction
# Processing Record 44 of Set 10 | Iki-Burul
# Processing Record 45 of Set 10 | Tayshet
# Processing Record 46 of Set 10 | Neverkino
# City not found. Skipping...
# Processing Record 48 of Set 10 | Sangar
# Processing Record 49 of Set 10 | Panzhihua
# Processing Record 50 of Set 10 | Ulaangom
# Resting...
# Processing Record 1 of Set 11 | Sur
# Processing Record 2 of Set 11 | Lodwar
# Processing Record 3 of Set 11 | Prado
# Processing Record 4 of Set 11 | La Ronge
# Processing Record 5 of Set 11 | Cairns
# Processing Record 6 of Set 11 | Novyy Yegorlyk
# Processing Record 7 of Set 11 | Araceli
# Processing Record 8 of Set 11 | Ziro
# Processing Record 9 of Set 11 | Sterling
# Processing Record 10 of Set 11 | Opuwo
# Processing Record 11 of Set 11 | Ranavav
# Processing Record 12 of Set 11 | Bapatla
# Processing Record 13 of Set 11 | Nhulunbuy
# Processing Record 14 of Set 11 | Beruwala
# Processing Record 15 of Set 11 | Baykit
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 18 of Set 11 | Ballina
# Processing Record 19 of Set 11 | Omboue
# Processing Record 20 of Set 11 | Vilyuysk
# Processing Record 21 of Set 11 | Christchurch
# Processing Record 22 of Set 11 | Marquette
# Processing Record 23 of Set 11 | Xocali
# Processing Record 24 of Set 11 | Nome
# City not found. Skipping...
# Processing Record 26 of Set 11 | Sola
# Processing Record 27 of Set 11 | Shakawe
# Processing Record 28 of Set 11 | Listvyanka
# Processing Record 29 of Set 11 | Mahon
# Processing Record 30 of Set 11 | Alyangula
# Processing Record 31 of Set 11 | Karasburg
# Processing Record 32 of Set 11 | Kavali
# Processing Record 33 of Set 11 | Clarksburg
# Processing Record 34 of Set 11 | El Vigia
# Processing Record 35 of Set 11 | Caravelas
# Processing Record 36 of Set 11 | Santa Cruz Cabralia
# Processing Record 37 of Set 11 | Sabya
# Processing Record 38 of Set 11 | Mumford
# Processing Record 39 of Set 11 | Dunedin
# Processing Record 40 of Set 11 | Necochea
# Processing Record 41 of Set 11 | Luganville
# City not found. Skipping...
# Processing Record 43 of Set 11 | Marsa Matruh
# Processing Record 44 of Set 11 | Saint-Pierre
# Processing Record 45 of Set 11 | Kierspe
# Processing Record 46 of Set 11 | Pizarro
# Processing Record 47 of Set 11 | Nagydorog
# Processing Record 48 of Set 11 | Qandala
# Processing Record 49 of Set 11 | Arlit
# City not found. Skipping...
# Resting...
# Processing Record 1 of Set 12 | Berlevag
# Processing Record 2 of Set 12 | Carbonear
# Processing Record 3 of Set 12 | Byron Bay
# Processing Record 4 of Set 12 | Matay
# Processing Record 5 of Set 12 | Kieta
# Processing Record 6 of Set 12 | San Luis
# Processing Record 7 of Set 12 | Coquimbo
# Processing Record 8 of Set 12 | Quatre Cocos
# Processing Record 9 of Set 12 | Mount Pleasant
# Processing Record 10 of Set 12 | Urubicha
# City not found. Skipping...
# Processing Record 12 of Set 12 | Fortuna
# City not found. Skipping...
# Processing Record 14 of Set 12 | Melton
# Processing Record 15 of Set 12 | Elko
# Processing Record 16 of Set 12 | Ornskoldsvik
# Processing Record 17 of Set 12 | Sosnovo-Ozerskoye
# Processing Record 18 of Set 12 | Shaunavon
# Processing Record 19 of Set 12 | Maceio
# Processing Record 20 of Set 12 | Taraclia
# Processing Record 21 of Set 12 | Grand-Lahou
# Processing Record 22 of Set 12 | Maldonado
# Processing Record 23 of Set 12 | Zhigansk
# City not found. Skipping...
# Processing Record 25 of Set 12 | Sisophon
# Processing Record 26 of Set 12 | Aksu
# Processing Record 27 of Set 12 | Florence
# Processing Record 28 of Set 12 | Sawtell
# Processing Record 29 of Set 12 | Stepanov
# Processing Record 30 of Set 12 | Bad Doberan
# Processing Record 31 of Set 12 | Sulangan
# City not found. Skipping...
# Processing Record 33 of Set 12 | Marawi
# Processing Record 34 of Set 12 | Iquitos
# City not found. Skipping...
# Processing Record 36 of Set 12 | Oistins
# Processing Record 37 of Set 12 | Barabash
# Processing Record 38 of Set 12 | Cayenne
# Processing Record 39 of Set 12 | Pouebo
# Processing Record 40 of Set 12 | Ewa Beach
# Processing Record 41 of Set 12 | Umm Lajj
# Processing Record 42 of Set 12 | Kibala
# Processing Record 43 of Set 12 | Nadym
# Processing Record 44 of Set 12 | Karla
# Processing Record 45 of Set 12 | Izumo
# Processing Record 46 of Set 12 | Kasempa
# City not found. Skipping...
# Processing Record 48 of Set 12 | Orotukan
# Processing Record 49 of Set 12 | Hadejia
# Processing Record 50 of Set 12 | Dunkirk
# Resting...
# Processing Record 1 of Set 13 | Tsiroanomandidy
# Processing Record 2 of Set 13 | Vostok
# Processing Record 3 of Set 13 | Kupang
# Processing Record 4 of Set 13 | Ormond Beach
# Processing Record 5 of Set 13 | Carauari
# Processing Record 6 of Set 13 | Antu
# Processing Record 7 of Set 13 | Huilong
# City not found. Skipping...
# Processing Record 9 of Set 13 | Vestmannaeyjar
# Processing Record 10 of Set 13 | La Sarre
# Last Call
# 65 cities returned KeyErrors and were skipped

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    
    "City" : name_info,
    "Cloudiness" : cloud_info,
    "Country" : country_info,
    "Date" : date_info,
    "Humidity" : humidity_info,
    "Latitude" : lat_info,
    "Longitude" : lon_info,
    "Temperature Max" : temp_max,
    "Wind Speed" : wind_speed,
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City               545
# Cloudiness         545
# Country            545
# Date               545
# Humidity           545
# Latitude           545
# Longitude          545
# Temperature Max    545
# Wind Speed         545
# dtype: int64

# %%
# Export the city data into a .csv
weather_data.to_csv('output_data/weather_data.csv')

#Display the DataFrame
weather_data.head()
# Out:
#         City  Cloudiness Country        Date  Humidity  Latitude  Longitude  \
# 0   Souillac           0      FR  1559364358        82     45.60      -0.60
# 1    Aksarka         100      RU  1559364359        80     66.56      67.80
# 2   Hermanus          11      ZA  1559364341        92    -34.42      19.24
# 3  Kununurra           0      AU  1559364359        16    -15.77     128.74
# 4    Ushuaia          90      AR  1559364073        74    -54.81     -68.31
#
#    Temperature Max  Wind Speed
# 0            59.00        2.24
# 1            37.13        4.12
# 2            54.00        5.79
# 3            77.00       13.87
# 4            33.80       12.75

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(
    weather_data["Latitude"], 
    weather_data["Temperature Max"], 
    marker="o", 
    c='tab:blue',
    edgecolors='black',
    alpha=.8
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (06/01/19)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/LatitudeVsMaxTemp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(
    weather_data["Latitude"], 
    weather_data["Humidity"], 
    marker="o", 
    c='tab:blue',
    edgecolors='black',
    alpha=.8,
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (06/01/19)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/LatitudeVsHumidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(
    weather_data["Latitude"], 
    weather_data["Cloudiness"], 
    marker="o", 
    c='tab:blue',
    edgecolors='black',
    alpha=.8,
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (06/01/19)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/LatitudeVsCloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(
    weather_data["Latitude"], 
    weather_data["Wind Speed"], 
    marker="o", 
    c='tab:blue',
    edgecolors='black',
    alpha=.8,
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (06/01/19)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/LatitudeVsWindSpeed.png")

# Show plot
plt.show()
