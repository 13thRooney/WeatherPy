# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 590

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="


# Set up lists to hold response info
name_info = []
cloud_info = []
country_info = []
date_info = []
humidity_info = []
lat_info = []
lon_info = []   
temp_max = []
wind_speed = []

# Start the counters
count = 1 # counter to count the number of calls to API
err = 0 # error count to record how many cities the API responds back with no data.
sets = 1 # counter to count the number of call sets

#Get current time
t0 = time.time()

#Log file print statement
print(f"Beginning Data Retrieval \n------------------------------------")

# Loop through the list of cities and perform a request for data on each
for city in cities:
    try: 
        weather_response = requests.get(query_url + city)
        name_info.append(weather_response.json()['name'])
        cloud_info.append(weather_response.json()['clouds']['all'])
        country_info.append(weather_response.json()['sys']['country'])
        date_info.append(weather_response.json()['dt'])
        humidity_info.append(weather_response.json()['main']['humidity'])
        lat_info.append(weather_response.json()['coord']['lat'])
        lon_info.append(weather_response.json()['coord']['lon'])
        temp_max.append(weather_response.json()['main']['temp_max'])
        wind_speed.append(weather_response.json()['wind']['speed'])
        city_record = weather_response.json()['name']
    
        # Print call log counter
        print(f"Processing Record {count} of Set {sets} | {city_record}")
        print(f"{query_url + city}")
    
    # If no record found, skip to the next API call      
    except KeyError:
        print("City not found. Skipping...")
        err= err+1
    # Increase counter by one
    count = count + 1  
    if count == 51: # loop to limit 50 API calls per minute. The API is capped at 60 per min.
        print("Resting...")
        t1=time.time()
        count = 1 
        sets = sets+1
        time.sleep(60-(t1-t0))
        t0 = time.time()
        
print("Last Call")
print(f'{err} cities returned KeyErrors and were skipped')
# Out:
# Beginning Data Retrieval
# ------------------------------------
# Processing Record 1 of Set 1 | Puerto Leguizamo
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=puerto leguizamo
# Processing Record 2 of Set 1 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=klaksvik
# Processing Record 3 of Set 1 | Avarua
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=avarua
# Processing Record 4 of Set 1 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=port elizabeth
# Processing Record 5 of Set 1 | Busselton
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=busselton
# Processing Record 6 of Set 1 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=hermanus
# Processing Record 7 of Set 1 | Teguldet
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=teguldet
# Processing Record 8 of Set 1 | Merauke
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=merauke
# Processing Record 9 of Set 1 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=clyde river
# Processing Record 10 of Set 1 | Kalmunai
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=kalmunai
# Processing Record 11 of Set 1 | Alta Floresta
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=alta floresta
# Processing Record 12 of Set 1 | Mataura
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=mataura
# Processing Record 13 of Set 1 | Ambon
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=ambon
# Processing Record 14 of Set 1 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=hithadhoo
# Processing Record 15 of Set 1 | Barrow
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=barrow
# Processing Record 16 of Set 1 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=saint-philippe
# Processing Record 17 of Set 1 | Hobart
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=hobart
# Processing Record 18 of Set 1 | Hilo
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=hilo
# Processing Record 19 of Set 1 | Arman
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=arman
# Processing Record 20 of Set 1 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=mar del plata
# City not found. Skipping...
# Processing Record 22 of Set 1 | Plastun
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=plastun
# Processing Record 23 of Set 1 | Castro
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=castro
# City not found. Skipping...
# Processing Record 25 of Set 1 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=kapaa
# Processing Record 26 of Set 1 | Gat
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=gat
# Processing Record 27 of Set 1 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=ushuaia
# Processing Record 28 of Set 1 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=tuktoyaktuk
# Processing Record 29 of Set 1 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=cidreira
# Processing Record 30 of Set 1 | Darhan
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=darhan
# City not found. Skipping...
# Processing Record 32 of Set 1 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=mahebourg
# Processing Record 33 of Set 1 | Nanuque
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=nanuque
# Processing Record 34 of Set 1 | Hilpoltstein
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=hilpoltstein
# Processing Record 35 of Set 1 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=kodiak
# Processing Record 36 of Set 1 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=jamestown
# Processing Record 37 of Set 1 | Poum
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=poum
# Processing Record 38 of Set 1 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=hobyo
# Processing Record 39 of Set 1 | Pasni
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=pasni
# City not found. Skipping...
# Processing Record 41 of Set 1 | Tornio
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=tornio
# Processing Record 42 of Set 1 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=cape town
# Processing Record 43 of Set 1 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=kavieng
# Processing Record 44 of Set 1 | Ust-Kulom
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=ust-kulom
# Processing Record 45 of Set 1 | Frankenberg
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=frankenberg
# Processing Record 46 of Set 1 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=port alfred
# Processing Record 47 of Set 1 | Senanga
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=senanga
# City not found. Skipping...
# Processing Record 49 of Set 1 | Ambilobe
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=ambilobe
# Processing Record 50 of Set 1 | Nemuro
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=nemuro
# Resting...
# City not found. Skipping...
# Processing Record 2 of Set 2 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=kruisfontein
# Processing Record 3 of Set 2 | Morondava
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=morondava
# Processing Record 4 of Set 2 | Bethel
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=bethel
# Processing Record 5 of Set 2 | Jenbach
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=jenbach
# Processing Record 6 of Set 2 | Bryan
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=bryan
# Processing Record 7 of Set 2 | Teya
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=teya
# Processing Record 8 of Set 2 | Waipawa
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=waipawa
# Processing Record 9 of Set 2 | Lebu
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=lebu
# Processing Record 10 of Set 2 | Pevek
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=pevek
# Processing Record 11 of Set 2 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=qaanaaq
# City not found. Skipping...
# Processing Record 13 of Set 2 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=kaitangata
# Processing Record 14 of Set 2 | Husavik
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=husavik
# Processing Record 15 of Set 2 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=ribeira grande
# Processing Record 16 of Set 2 | Kahului
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=kahului
# Processing Record 17 of Set 2 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=caravelas
# Processing Record 18 of Set 2 | Mikumi
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=mikumi
# City not found. Skipping...
# Processing Record 20 of Set 2 | Connersville
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=connersville
# Processing Record 21 of Set 2 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=bambous virieux
# Processing Record 22 of Set 2 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=rikitea
# Processing Record 23 of Set 2 | Gimli
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=gimli
# Processing Record 24 of Set 2 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=longyearbyen
# City not found. Skipping...
# Processing Record 26 of Set 2 | Carberry
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=carberry
# Processing Record 27 of Set 2 | Airai
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=airai
# Processing Record 28 of Set 2 | Lerwick
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=lerwick
# Processing Record 29 of Set 2 | Finnsnes
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=finnsnes
# Processing Record 30 of Set 2 | Natal
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=natal
# City not found. Skipping...
# Processing Record 32 of Set 2 | Tezu
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=tezu
# Processing Record 33 of Set 2 | Faanui
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=faanui
# Processing Record 34 of Set 2 | Albany
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=albany
# Processing Record 35 of Set 2 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=khatanga
# Processing Record 36 of Set 2 | Tazmalt
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=tazmalt
# Processing Record 37 of Set 2 | Rantauprapat
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=rantauprapat
# Processing Record 38 of Set 2 | Skibbereen
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=skibbereen
# Processing Record 39 of Set 2 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=los llanos de aridane
# Processing Record 40 of Set 2 | Boueni
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=boueni
# Processing Record 41 of Set 2 | Xuddur
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=xuddur
# Processing Record 42 of Set 2 | Axim
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=axim
# Processing Record 43 of Set 2 | Aljezur
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=aljezur
# Processing Record 44 of Set 2 | Vaini
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=vaini
# Processing Record 45 of Set 2 | Margate
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=margate
# Processing Record 46 of Set 2 | Ostersund
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=ostersund
# City not found. Skipping...
# Processing Record 48 of Set 2 | Forestville
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=forestville
# Processing Record 49 of Set 2 | Bluff
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=bluff
# Processing Record 50 of Set 2 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=fortuna
# Resting...
# Processing Record 1 of Set 3 | Lasa
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=lasa
# Processing Record 2 of Set 3 | Troitsko-Pechorsk
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=troitsko-pechorsk
# Processing Record 3 of Set 3 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=arraial do cabo
# Processing Record 4 of Set 3 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=new norfolk
# Processing Record 5 of Set 3 | Acapulco
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=acapulco
# Processing Record 6 of Set 3 | Komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=komsomolskiy
# Processing Record 7 of Set 3 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=port blair
# Processing Record 8 of Set 3 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=sao joao da barra
# Processing Record 9 of Set 3 | Atuona
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=atuona
# Processing Record 10 of Set 3 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=bredasdorp
# Processing Record 11 of Set 3 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=lorengau
# Processing Record 12 of Set 3 | Naze
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=naze
# Processing Record 13 of Set 3 | Port Macquarie
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=port macquarie
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 16 of Set 3 | Valparaiso
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=valparaiso
# Processing Record 17 of Set 3 | Athabasca
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=athabasca
# Processing Record 18 of Set 3 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=te anau
# Processing Record 19 of Set 3 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=puerto ayora
# Processing Record 20 of Set 3 | Manokwari
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=manokwari
# Processing Record 21 of Set 3 | Luwuk
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=luwuk
# Processing Record 22 of Set 3 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=punta arenas
# Processing Record 23 of Set 3 | Qaqortoq
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=qaqortoq
# Processing Record 24 of Set 3 | Egvekinot
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=egvekinot
# Processing Record 25 of Set 3 | Yeppoon
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=yeppoon
# Processing Record 26 of Set 3 | Yakovlevka
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=yakovlevka
# Processing Record 27 of Set 3 | Thunder Bay
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=thunder bay
# City not found. Skipping...
# Processing Record 29 of Set 3 | Cascais
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=cascais
# Processing Record 30 of Set 3 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=butaritari
# Processing Record 31 of Set 3 | Peniche
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=peniche
# Processing Record 32 of Set 3 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=saint-augustin
# Processing Record 33 of Set 3 | Karratha
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=karratha
# Processing Record 34 of Set 3 | Carupano
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=carupano
# Processing Record 35 of Set 3 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=yellowknife
# Processing Record 36 of Set 3 | Saravan
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=saravan
# City not found. Skipping...
# Processing Record 38 of Set 3 | Saint-Leu
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=saint-leu
# Processing Record 39 of Set 3 | Sokoni
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=sokoni
# Processing Record 40 of Set 3 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=constitucion
# Processing Record 41 of Set 3 | Chuy
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=chuy
# Processing Record 42 of Set 3 | Shimoda
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=shimoda
# Processing Record 43 of Set 3 | Juneau
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=juneau
# Processing Record 44 of Set 3 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=pangnirtung
# Processing Record 45 of Set 3 | Pearl Lagoon
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=laguna de perlas
# Processing Record 46 of Set 3 | Badnawar
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=badnawar
# Processing Record 47 of Set 3 | Tura
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=tura
# Processing Record 48 of Set 3 | Zelenoborskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=zelenoborskiy
# Processing Record 49 of Set 3 | Porto Novo
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=porto novo
# Processing Record 50 of Set 3 | Kupang
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=kupang
# Resting...
# Processing Record 1 of Set 4 | Harper
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=harper
# Processing Record 2 of Set 4 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=chokurdakh
# Processing Record 3 of Set 4 | Channarayapatna
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=channarayapatna
# Processing Record 4 of Set 4 | Darab
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=darab
# Processing Record 5 of Set 4 | Alofi
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=alofi
# Processing Record 6 of Set 4 | Tingo Maria
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=tingo maria
# Processing Record 7 of Set 4 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=georgetown
# Processing Record 8 of Set 4 | Sabaudia
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=sabaudia
# Processing Record 9 of Set 4 | Iquitos
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=iquitos
# Processing Record 10 of Set 4 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=tiksi
# Processing Record 11 of Set 4 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=upernavik
# Processing Record 12 of Set 4 | Yulin
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=yulin
# Processing Record 13 of Set 4 | Alaca
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=alaca
# Processing Record 14 of Set 4 | Wucheng
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=wucheng
# City not found. Skipping...
# Processing Record 16 of Set 4 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=saskylakh
# Processing Record 17 of Set 4 | Brae
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=brae
# City not found. Skipping...
# Processing Record 19 of Set 4 | Ajaccio
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=ajaccio
# Processing Record 20 of Set 4 | Saint Anthony
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=saint anthony
# Processing Record 21 of Set 4 | Vysokogornyy
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=vysokogornyy
# Processing Record 22 of Set 4 | Lata
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=lata
# Processing Record 23 of Set 4 | Natchez
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=natchez
# Processing Record 24 of Set 4 | Betafo
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=betafo
# Processing Record 25 of Set 4 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=vila velha
# Processing Record 26 of Set 4 | Victoria
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=victoria
# Processing Record 27 of Set 4 | Koumac
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=koumac
# Processing Record 28 of Set 4 | Soe
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=soe
# Processing Record 29 of Set 4 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=iqaluit
# Processing Record 30 of Set 4 | Half Moon Bay
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=half moon bay
# Processing Record 31 of Set 4 | Pomabamba
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=pomabamba
# Processing Record 32 of Set 4 | Labuhan
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=labuhan
# Processing Record 33 of Set 4 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=sao filipe
# Processing Record 34 of Set 4 | Saintes
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=saintes
# Processing Record 35 of Set 4 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=ilulissat
# Processing Record 36 of Set 4 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=lagoa
# Processing Record 37 of Set 4 | Meulaboh
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=meulaboh
# Processing Record 38 of Set 4 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=provideniya
# Processing Record 39 of Set 4 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=tuatapere
# City not found. Skipping...
# Processing Record 41 of Set 4 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=port lincoln
# Processing Record 42 of Set 4 | Varhaug
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=varhaug
# Processing Record 43 of Set 4 | Belyy Yar
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=belyy yar
# Processing Record 44 of Set 4 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=carnarvon
# Processing Record 45 of Set 4 | Bartica
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=bartica
# Processing Record 46 of Set 4 | Carutapera
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=carutapera
# Processing Record 47 of Set 4 | Namtsy
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=namtsy
# City not found. Skipping...
# Processing Record 49 of Set 4 | Nioro
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=nioro
# Processing Record 50 of Set 4 | Hovd
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=hovd
# Resting...
# Processing Record 1 of Set 5 | Verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=verkhoyansk
# Processing Record 2 of Set 5 | Lixourion
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=lixourion
# Processing Record 3 of Set 5 | Camacupa
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=camacupa
# Processing Record 4 of Set 5 | Praia
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=praia
# Processing Record 5 of Set 5 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=narsaq
# Processing Record 6 of Set 5 | Amnat Charoen
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=amnat charoen
# Processing Record 7 of Set 5 | Hirara
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=hirara
# City not found. Skipping...
# Processing Record 9 of Set 5 | Souillac
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=souillac
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 12 of Set 5 | Jepara
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=jepara
# Processing Record 13 of Set 5 | San Quintin
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=san quintin
# Processing Record 14 of Set 5 | Chara
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=chara
# Processing Record 15 of Set 5 | Torbay
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=torbay
# Processing Record 16 of Set 5 | Parthenay
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=parthenay
# Processing Record 17 of Set 5 | Dikson
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=dikson
# Processing Record 18 of Set 5 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=tasiilaq
# Processing Record 19 of Set 5 | Vestmanna
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=vestmanna
# Processing Record 20 of Set 5 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=norman wells
# Processing Record 21 of Set 5 | Nishihara
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=nishihara
# Processing Record 22 of Set 5 | Mersing
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=mersing
# Processing Record 23 of Set 5 | Isla Mujeres
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=isla mujeres
# Processing Record 24 of Set 5 | Ust-Kuyga
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=ust-kuyga
# Processing Record 25 of Set 5 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=fairbanks
# Processing Record 26 of Set 5 | Khasan
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=khasan
# Processing Record 27 of Set 5 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=zhigansk
# Processing Record 28 of Set 5 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=ponta do sol
# Processing Record 29 of Set 5 | Kalianget
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=kalianget
# Processing Record 30 of Set 5 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=aklavik
# Processing Record 31 of Set 5 | Sambava
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=sambava
# Processing Record 32 of Set 5 | Yakuplu
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=yakuplu
# Processing Record 33 of Set 5 | Moron
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=moron
# Processing Record 34 of Set 5 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=nikolskoye
# Processing Record 35 of Set 5 | Tigzirt
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=tigzirt
# Processing Record 36 of Set 5 | Flin Flon
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=flin flon
# Processing Record 37 of Set 5 | Piranhas
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=piranhas
# Processing Record 38 of Set 5 | Ocos
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=ocos
# Processing Record 39 of Set 5 | Teeli
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=teeli
# Processing Record 40 of Set 5 | Taoudenni
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=taoudenni
# Processing Record 41 of Set 5 | Gloversville
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=gloversville
# Processing Record 42 of Set 5 | Teahupoo
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=teahupoo
# Processing Record 43 of Set 5 | Kalaleh
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=kalaleh
# Processing Record 44 of Set 5 | Hami
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=hami
# Processing Record 45 of Set 5 | Atbasar
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=atbasar
# Processing Record 46 of Set 5 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=katsuura
# City not found. Skipping...
# Processing Record 48 of Set 5 | Tevaitoa
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=tevaitoa
# Processing Record 49 of Set 5 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=cherskiy
# Processing Record 50 of Set 5 | East London
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=east london
# Resting...
# Processing Record 1 of Set 6 | Igrim
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=igrim
# Processing Record 2 of Set 6 | Kjollefjord
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=kjollefjord
# Processing Record 3 of Set 6 | Roald
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=roald
# Processing Record 4 of Set 6 | Esperance
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=esperance
# Processing Record 5 of Set 6 | Litovko
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=litovko
# City not found. Skipping...
# Processing Record 7 of Set 6 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=nanortalik
# Processing Record 8 of Set 6 | Ancud
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=ancud
# Processing Record 9 of Set 6 | Veraval
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=veraval
# Processing Record 10 of Set 6 | Saint George
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=saint george
# Processing Record 11 of Set 6 | Wenatchee
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=wenatchee
# Processing Record 12 of Set 6 | Lubu
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=lubu
# Processing Record 13 of Set 6 | Khandyga
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=khandyga
# Processing Record 14 of Set 6 | Beringovskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=beringovskiy
# Processing Record 15 of Set 6 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=san cristobal
# Processing Record 16 of Set 6 | Gizo
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=gizo
# City not found. Skipping...
# Processing Record 18 of Set 6 | Porto Belo
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=porto belo
# Processing Record 19 of Set 6 | Mumford
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=mumford
# Processing Record 20 of Set 6 | Namatanai
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=namatanai
# Processing Record 21 of Set 6 | Zlate Moravce
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=zlate moravce
# City not found. Skipping...
# Processing Record 23 of Set 6 | Bose
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=bose
# Processing Record 24 of Set 6 | Mahajanga
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=mahajanga
# Processing Record 25 of Set 6 | Tucupita
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=tucupita
# Processing Record 26 of Set 6 | Omsukchan
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=omsukchan
# Processing Record 27 of Set 6 | Mongo
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=mongo
# Processing Record 28 of Set 6 | Mehran
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=mehran
# Processing Record 29 of Set 6 | Outjo
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=outjo
# Processing Record 30 of Set 6 | Estancia
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=estancia
# Processing Record 31 of Set 6 | Shenjiamen
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=shenjiamen
# Processing Record 32 of Set 6 | Padang
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=padang
# Processing Record 33 of Set 6 | Izhma
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=izhma
# Processing Record 34 of Set 6 | Bilibino
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=bilibino
# Processing Record 35 of Set 6 | Guaimaro
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=guaimaro
# City not found. Skipping...
# Processing Record 37 of Set 6 | Boende
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=boende
# Processing Record 38 of Set 6 | Ewa Beach
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=ewa beach
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 41 of Set 6 | Pozo Colorado
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=pozo colorado
# Processing Record 42 of Set 6 | Wawa
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=wawa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 6 | Aksaray
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=aksaray
# City not found. Skipping...
# Processing Record 47 of Set 6 | Diamantino
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=diamantino
# City not found. Skipping...
# Processing Record 49 of Set 6 | Ushumun
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=ushumun
# Processing Record 50 of Set 6 | Raudeberg
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=raudeberg
# Resting...
# Processing Record 1 of Set 7 | Bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=bandarbeyla
# Processing Record 2 of Set 7 | Boa Vista
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=boa vista
# Processing Record 3 of Set 7 | Wadi Maliz
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=wadi maliz
# City not found. Skipping...
# Processing Record 5 of Set 7 | Kobryn
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=kobryn
# Processing Record 6 of Set 7 | Hualmay
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=hualmay
# Processing Record 7 of Set 7 | Melfi
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=melfi
# Processing Record 8 of Set 7 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=leningradskiy
# Processing Record 9 of Set 7 | Aranos
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=aranos
# Processing Record 10 of Set 7 | Awbari
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=awbari
# Processing Record 11 of Set 7 | Comodoro Rivadavia
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=comodoro rivadavia
# Processing Record 12 of Set 7 | Avallon
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=avallon
# Processing Record 13 of Set 7 | Vardo
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=vardo
# Processing Record 14 of Set 7 | Yulara
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=yulara
# Processing Record 15 of Set 7 | Pennagaram
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=pennagaram
# Processing Record 16 of Set 7 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=guerrero negro
# Processing Record 17 of Set 7 | Robertsganj
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=robertsganj
# Processing Record 18 of Set 7 | Kadipur
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=kadipur
# Processing Record 19 of Set 7 | Campo Grande
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=campo grande
# Processing Record 20 of Set 7 | Berlevag
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=berlevag
# Processing Record 21 of Set 7 | Zakamensk
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=zakamensk
# Processing Record 22 of Set 7 | Westport
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=westport
# Processing Record 23 of Set 7 | Mirnyy
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=mirnyy
# Processing Record 24 of Set 7 | Surt
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=surt
# Processing Record 25 of Set 7 | Butembo
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=butembo
# Processing Record 26 of Set 7 | Omboue
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=omboue
# Processing Record 27 of Set 7 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=hamilton
# Processing Record 28 of Set 7 | Kinsale
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=kinsale
# Processing Record 29 of Set 7 | Bang Saphan
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=bang saphan
# Processing Record 30 of Set 7 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=bathsheba
# Processing Record 31 of Set 7 | Upata
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=upata
# Processing Record 32 of Set 7 | Taltal
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=taltal
# Processing Record 33 of Set 7 | Limon
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=limon
# Processing Record 34 of Set 7 | Saquarema
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=saquarema
# Processing Record 35 of Set 7 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=cabo san lucas
# Processing Record 36 of Set 7 | Vao
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=vao
# Processing Record 37 of Set 7 | Makakilo City
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=makakilo city
# City not found. Skipping...
# Processing Record 39 of Set 7 | Neuquen
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=neuquen
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 7 | Krasnyy Chikoy
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=krasnyy chikoy
# Processing Record 43 of Set 7 | Vila
# ...
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=newtonmore
# Processing Record 28 of Set 10 | Dvinskoy
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=dvinskoy
# Processing Record 29 of Set 10 | Mayo
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=mayo
# Processing Record 30 of Set 10 | Araouane
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=araouane
# Processing Record 31 of Set 10 | Nome
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=nome
# City not found. Skipping...
# Processing Record 33 of Set 10 | Emerald
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=emerald
# Processing Record 34 of Set 10 | Yerbogachen
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=yerbogachen
# Processing Record 35 of Set 10 | Pontalina
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=pontalina
# Processing Record 36 of Set 10 | Wanaka
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=wanaka
# Processing Record 37 of Set 10 | Waingapu
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=waingapu
# Processing Record 38 of Set 10 | North Bend
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=north bend
# City not found. Skipping...
# Processing Record 40 of Set 10 | Ajdabiya
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=ajdabiya
# Processing Record 41 of Set 10 | Cabatuan
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=cabatuan
# Processing Record 42 of Set 10 | Juybar
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=juybar
# Processing Record 43 of Set 10 | Asbestos
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=asbestos
# Processing Record 44 of Set 10 | Garissa
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=garissa
# Processing Record 45 of Set 10 | Makinsk
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=makinsk
# Processing Record 46 of Set 10 | Buin
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=buin
# City not found. Skipping...
# Processing Record 48 of Set 10 | Xixiang
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=xixiang
# Processing Record 49 of Set 10 | Paita
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=paita
# Processing Record 50 of Set 10 | Krasnoborsk
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=krasnoborsk
# Resting...
# Processing Record 1 of Set 11 | Tiznit
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=tiznit
# Processing Record 2 of Set 11 | Merritt Island
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=merritt island
# Processing Record 3 of Set 11 | Arlit
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=arlit
# City not found. Skipping...
# Processing Record 5 of Set 11 | Beloha
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=beloha
# Processing Record 6 of Set 11 | Kamenka
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=kamenka
# Processing Record 7 of Set 11 | Divnogorsk
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=divnogorsk
# Processing Record 8 of Set 11 | Maragogi
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=maragogi
# Processing Record 9 of Set 11 | Roebourne
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=roebourne
# Processing Record 10 of Set 11 | Hay River
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=hay river
# City not found. Skipping...
# Processing Record 12 of Set 11 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=dunedin
# Processing Record 13 of Set 11 | Galesong
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=galesong
# Processing Record 14 of Set 11 | Baykit
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=baykit
# Processing Record 15 of Set 11 | Iquique
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=iquique
# Processing Record 16 of Set 11 | Isangel
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=isangel
# Processing Record 17 of Set 11 | Dauphin
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=dauphin
# Processing Record 18 of Set 11 | Krasnouralsk
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=krasnouralsk
# Processing Record 19 of Set 11 | Santa Vitoria do Palmar
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=santa vitoria do palmar
# Processing Record 20 of Set 11 | Broome
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=broome
# Processing Record 21 of Set 11 | Grand Gaube
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=grand gaube
# Processing Record 22 of Set 11 | The Pas
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=the pas
# Processing Record 23 of Set 11 | Goya
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=goya
# Processing Record 24 of Set 11 | Marawi
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=marawi
# Processing Record 25 of Set 11 | Victor Harbor
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=victor harbor
# Processing Record 26 of Set 11 | Quatre Cocos
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=quatre cocos
# Processing Record 27 of Set 11 | Jian
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=jian
# Processing Record 28 of Set 11 | Cumpas
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=cumpas
# City not found. Skipping...
# Processing Record 30 of Set 11 | Saint-Louis
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=saint-louis
# Processing Record 31 of Set 11 | Acajutla
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=acajutla
# Processing Record 32 of Set 11 | Cedar City
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=cedar city
# Processing Record 33 of Set 11 | Okha
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=okha
# Processing Record 34 of Set 11 | Uri
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=uri
# Processing Record 35 of Set 11 | Portland
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=portland
# Processing Record 36 of Set 11 | Dingle
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=dingle
# Processing Record 37 of Set 11 | Bay Roberts
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=bay roberts
# Processing Record 38 of Set 11 | Mirabela
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=mirabela
# Processing Record 39 of Set 11 | Vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=vestmannaeyjar
# Processing Record 40 of Set 11 | Nalut
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=nalut
# Processing Record 41 of Set 11 | Plettenberg Bay
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=plettenberg bay
# City not found. Skipping...
# Processing Record 43 of Set 11 | Fare
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=fare
# Processing Record 44 of Set 11 | Rioja
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=rioja
# Processing Record 45 of Set 11 | Moura
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=moura
# Processing Record 46 of Set 11 | College
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=college
# City not found. Skipping...
# Processing Record 48 of Set 11 | Samarai
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=samarai
# Processing Record 49 of Set 11 | Port-Cartier
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=port-cartier
# Processing Record 50 of Set 11 | Santa Rosalia
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=santa rosalia
# Resting...
# Processing Record 1 of Set 12 | Vigrestad
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=vigrestad
# Processing Record 2 of Set 12 | Scarborough
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=scarborough
# Processing Record 3 of Set 12 | Eyrarbakki
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=eyrarbakki
# Processing Record 4 of Set 12 | Lejanias
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=lejanias
# Processing Record 5 of Set 12 | Baijiantan
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=baijiantan
# Processing Record 6 of Set 12 | Wajir
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=wajir
# Processing Record 7 of Set 12 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=srednekolymsk
# Processing Record 8 of Set 12 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=mehamn
# Processing Record 9 of Set 12 | Havre-Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=havre-saint-pierre
# Processing Record 10 of Set 12 | Morbach
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=morbach
# City not found. Skipping...
# Processing Record 12 of Set 12 | Biak
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=biak
# Processing Record 13 of Set 12 | Bunia
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=bunia
# Processing Record 14 of Set 12 | Tunceli
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=tunceli
# Processing Record 15 of Set 12 | Prince Rupert
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=prince rupert
# Processing Record 16 of Set 12 | Quartucciu
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=quartucciu
# Processing Record 17 of Set 12 | Alghero
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=alghero
# Processing Record 18 of Set 12 | Brest
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=brest
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 21 of Set 12 | Kuytun
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=kuytun
# City not found. Skipping...
# Processing Record 23 of Set 12 | Kathmandu
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=kathmandu
# Processing Record 24 of Set 12 | Phayakkhaphum Phisai
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=phayakkhaphum phisai
# Processing Record 25 of Set 12 | Yenagoa
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=yenagoa
# Processing Record 26 of Set 12 | Helong
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=helong
# Processing Record 27 of Set 12 | Mount Isa
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=mount isa
# Processing Record 28 of Set 12 | Miles City
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=miles city
# Processing Record 29 of Set 12 | Vostok
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=vostok
# Processing Record 30 of Set 12 | Kamaishi
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=kamaishi
# Processing Record 31 of Set 12 | Tupiza
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=tupiza
# Processing Record 32 of Set 12 | Quesnel
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=quesnel
# Processing Record 33 of Set 12 | Inhambane
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=inhambane
# Processing Record 34 of Set 12 | Nata
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=nata
# Processing Record 35 of Set 12 | Ereymentau
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=ereymentau
# Processing Record 36 of Set 12 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=severo-kurilsk
# Processing Record 37 of Set 12 | Opuwo
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=opuwo
# City not found. Skipping...
# Processing Record 39 of Set 12 | Tauramena
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=tauramena
# Processing Record 40 of Set 12 | Wamba
# http://api.openweathermap.org/data/2.5/weather?appid=f4a0f7b34e475e72efcf607750b2b1fc&units=imperial&q=wamba
# Last Call
# 61 cities returned KeyErrors and were skipped

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    
    "City" : name_info,
    "Cloudiness" : cloud_info,
    "Country" : country_info,
    "Date" : date_info,
    "Humidity" : humidity_info,
    "Latitude" : lat_info,
    "Longitude" : lon_info,
    "Temperature Max" : temp_max,
    "Wind Speed" : wind_speed,
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City               529
# Cloudiness         529
# Country            529
# Date               529
# Humidity           529
# Latitude           529
# Longitude          529
# Temperature Max    529
# Wind Speed         529
# dtype: int64

# %%
# Export the city data into a .csv
weather_data.to_csv('output_data/weather_data.csv')

#Display the DataFrame
weather_data.head()
# Out:
#                City  Cloudiness Country        Date  Humidity  Latitude  \
# 0  Puerto Leguizamo           0      CO  1559361633        84     -0.19
# 1          Klaksvik         100      FO  1559361633        87     62.23
# 2            Avarua           0      CK  1559361634        88    -21.21
# 3    Port Elizabeth           1      US  1559361349        93     39.31
# 4         Busselton          44      AU  1559361634        35    -33.64
#
#    Longitude  Temperature Max  Wind Speed
# 0     -74.78            75.66        2.30
# 1      -6.59            42.80        9.17
# 2    -159.78            75.20       12.75
# 3     -74.98            70.00        3.36
# 4     115.35            71.01       12.19

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(
    weather_data["Latitude"], 
    weather_data["Temperature Max"], 
    marker="o", 
    c='tab:blue',
    edgecolors='black',
    alpha=.8
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (06/01/19)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/LatitudeVsMaxTemp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(
    weather_data["Latitude"], 
    weather_data["Humidity"], 
    marker="o", 
    c='tab:blue',
    edgecolors='black',
    alpha=.8,
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (06/01/19)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/LatitudeVsHumidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(
    weather_data["Latitude"], 
    weather_data["Cloudiness"], 
    marker="o", 
    c='tab:blue',
    edgecolors='black',
    alpha=.8,
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (06/01/19)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/LatitudeVsCloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(
    weather_data["Latitude"], 
    weather_data["Wind Speed"], 
    marker="o", 
    c='tab:blue',
    edgecolors='black',
    alpha=.8,
)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (06/01/19)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/LatitudeVsWindSpeed.png")

# Show plot
plt.show()
